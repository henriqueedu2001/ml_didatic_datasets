# %% [markdown]
# # Datasets Didáticos

# %%
# importando bibliotecas padrão
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# importando ferramenta
from src.generator import Generator

# %% [markdown]
# ## Valores Numéricos Uniformemente Distribuídos

# %%
n, a, b = 50, -3, 12
uniform_dataset = Generator.generate_uniform_dist(n, a, b)

# %%
plt.hist(uniform_dataset)
plt.show()

# %% [markdown]
# ## Valores Numéricos con Distribuição Normal

# %%
n, mu, std_dev = 100, 6.1, 2.4
normal_dataset = Generator.generate_normal_dist(n, mu, std_dev)

# %%
plt.hist(normal_dataset)
plt.show()
